# %%
#https://pypi.org/project/bing-image-downloader/
# !pip install bing-image-downloader

# %%
search_term = "big tits"
search_term
# Out:
# 'big tits'

# %%
from bing_image_downloader import downloader
downloader.download(search_term, limit=100,  output_dir='dataset', adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 20 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://www.bustygirlsblog.com/galleries/karupsha/kha-valentine6_big.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://boobstr.com/galleries/curvy-bombshell-wendy-star-pours-milk-on-tits/7_big.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.hentai-and-fetish-galleries.com/galleries/hentai-big-tits/hentai-sex04.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.nudeglambabes.com/galleries/pics/photodromm/busty_nude_alexa_wet_beach04.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.bigtitsnews.net/img/091117/milena4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://www.maturexxxpics.net/images/af84b3/big-tits-blonde-mandi-mcgraw-mature-milf-12.jpg
# [%] File Downloaded !
#
# ...
